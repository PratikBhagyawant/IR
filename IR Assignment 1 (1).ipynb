# %% [markdown]
# **NAME** : Pratik Vijay Bhagyawant\
# **CLASS** : BE-AIDS\
# **ROLL No** : 2547008\
# **Batch** : A\
# **SUB** : Computer Laboratory II (Information Retrieval)

# %% [markdown]
# **Problem Statement**: Write a program for pre-processing of a text document such as stop word removal, stemming.

# %%
pip install nbconvert
# Out:
# Requirement already satisfied: nbconvert in /usr/lib/python3/dist-packages (5.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install inflect
# Out:
# Collecting inflect
#   Downloading inflect-7.4.0-py3-none-any.whl (34 kB)
# Collecting typing-extensions; python_version < "3.9"
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.1 MB/s eta 0:00:01
# Collecting typeguard>=4.0.1
#   Downloading typeguard-4.4.0-py3-none-any.whl (35 kB)
# Collecting more-itertools>=8.5.0
#   Downloading more_itertools-10.5.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 8.5 MB/s  eta 0:00:01
# Collecting importlib-metadata>=3.6; python_version < "3.10"
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: zipp>=3.20 in ./.local/lib/python3.8/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->typeguard>=4.0.1->inflect) (3.20.2)
# Installing collected packages: typing-extensions, importlib-metadata, typeguard, more-itertools, inflect
# Successfully installed importlib-metadata-8.5.0 inflect-7.4.0 more-itertools-10.5.0 typeguard-4.4.0 typing-extensions-4.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# Download punkt and punkt_tab (new requirement in latest NLTK versions)
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("averaged_perceptron_tagger")
nltk.download("averaged_perceptron_tagger_eng")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to /home/admin1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/admin1/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/admin1/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/admin1/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/admin1/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /home/admin1/nltk_data...
# True

# %%
import nltk
from nltk.corpus import wordnet,stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import inflect

# %%
document="Wow! Did you know that I have 10 Big red apples, 5 bananas, and 20 oranges, but only #3 are ripe enough to eat, and I still need to buy 15 more tomorrow? It's crazy how much fruit costs these days! 😅"

# %%
document=document.lower()
print(document)
# Out:
# wow! did you know that i have 10 big red apples, 5 bananas, and 20 oranges, but only #3 are ripe enough to eat, and i still need to buy 15 more tomorrow? it's crazy how much fruit costs these days! 😅

# %%
from nltk.tokenize import word_tokenize
tokenized=word_tokenize(document)
print(tokenized)
# Out:
# ['wow', '!', 'did', 'you', 'know', 'that', 'i', 'have', '10', 'big', 'red', 'apples', ',', '5', 'bananas', ',', 'and', '20', 'oranges', ',', 'but', 'only', '#', '3', 'are', 'ripe', 'enough', 'to', 'eat', ',', 'and', 'i', 'still', 'need', 'to', 'buy', '15', 'more', 'tomorrow', '?', 'it', "'s", 'crazy', 'how', 'much', 'fruit', 'costs', 'these', 'days', '!', '😅']

# %%
remove_punc=[i for i in tokenized if(i.isalnum())]
print(remove_punc)
# Out:
# ['wow', 'did', 'you', 'know', 'that', 'i', 'have', '10', 'big', 'red', 'apples', '5', 'bananas', 'and', '20', 'oranges', 'but', 'only', '3', 'are', 'ripe', 'enough', 'to', 'eat', 'and', 'i', 'still', 'need', 'to', 'buy', '15', 'more', 'tomorrow', 'it', 'crazy', 'how', 'much', 'fruit', 'costs', 'these', 'days']

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))
print(stop_words)
# Out:
# {'only', 's', "she'd", 'himself', 'itself', 'other', 'did', "it'll", 'so', 'nor', 'both', 'hadn', 'mightn', 'any', 'doesn', "needn't", "she'll", 'but', 'into', 'an', 'there', 'is', 'they', 'with', 'all', 'own', 'has', 'she', 'then', 'each', 'which', 'my', 'through', 'needn', 'o', 'who', 'when', 'will', "i'll", 'once', 'had', 'being', "shouldn't", "they're", 'these', 'until', 'above', 'mustn', "aren't", 'as', 'wouldn', "it'd", 'them', "isn't", 'than', "they'd", 'before', 'between', "didn't", 'shan', 'under', 'if', 'do', "he'll", 'don', 'where', 'didn', 'yours', 'your', "he'd", 'herself', 'doing', 'same', 'haven', 'in', "mustn't", 'on', "don't", "you'll", 'its', 'out', 'to', 'aren', 'and', "i'm", 'have', "they've", 'those', 'he', "wasn't", 'how', 'for', 'no', "haven't", 've', 'further', 'been', 'few', 'some', 'up', 'should', 'are', "we're", 'were', 'm', 'hers', 'here', "we'll", 'ma', 'at', 'you', "shan't", 'most', 'from', 'because', 'his', 'our', "wouldn't", 'yourselves', 'now', 'just', 'll', 'this', 'having', 'her', "weren't", "couldn't", "we'd", 'him', 'why', 'or', 're', 'it', 'can', 'ourselves', 'won', 'be', "hadn't", "that'll", 'we', 'what', 'their', 'of', "it's", 'over', 'd', "she's", 'themselves', 'very', 'ain', "he's", "won't", 'i', 'does', 'such', 'that', 'isn', 'ours', 'about', "mightn't", "we've", "hasn't", 'hasn', "i'd", 'yourself', 'below', 'again', 'myself', 'too', 'whom', "they'll", 't', 'by', "you'd", "i've", "should've", 'me', 'was', 'off', 'down', 'theirs', 'weren', 'couldn', 'not', 'while', 'the', 'after', 'am', 'more', 'during', 'a', 'y', 'against', "doesn't", 'shouldn', 'wasn', "you've", "you're"}

# %%
remove_stopwords=[i for i in remove_punc if i not in stop_words]
print(remove_stopwords)
# Out:
# ['wow', 'know', '10', 'big', 'red', 'apples', '5', 'bananas', '20', 'oranges', '3', 'ripe', 'enough', 'eat', 'still', 'need', 'buy', '15', 'tomorrow', 'crazy', 'much', 'fruit', 'costs', 'days']

# %%
import nltk
pos_tagged_tokens = nltk.pos_tag(remove_stopwords)
print(pos_tagged_tokens)
# Out:
# [('wow', 'NN'), ('know', 'VBP'), ('10', 'CD'), ('big', 'JJ'), ('red', 'JJ'), ('apples', 'NNS'), ('5', 'CD'), ('bananas', 'NNS'), ('20', 'CD'), ('oranges', 'NNS'), ('3', 'CD'), ('ripe', 'JJ'), ('enough', 'RB'), ('eat', 'NN'), ('still', 'RB'), ('need', 'VB'), ('buy', 'VB'), ('15', 'CD'), ('tomorrow', 'NN'), ('crazy', 'NN'), ('much', 'JJ'), ('fruit', 'NN'), ('costs', 'NNS'), ('days', 'NNS')]

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
lemmatized_text = []
for token, pos_tag in pos_tagged_tokens:
    wordnet_pos = get_wordnet_pos(pos_tag)
    lemmatized_word = lemmatizer.lemmatize(token, wordnet_pos)
    lemmatized_text.append(lemmatized_word)
print(lemmatized_text)
# Out:
# ['wow', 'know', '10', 'big', 'red', 'apple', '5', 'banana', '20', 'orange', '3', 'ripe', 'enough', 'eat', 'still', 'need', 'buy', '15', 'tomorrow', 'crazy', 'much', 'fruit', 'cost', 'day']

# %%
num2str = inflect.engine()
nums_to_string=[]
for i in lemmatized_text:
    if i.isdigit():
        nums_to_string.append(num2str.number_to_words(i))
    else:
        nums_to_string.append(i)
print(nums_to_string)
# Out:
# ['wow', 'know', 'ten', 'big', 'red', 'apple', 'five', 'banana', 'twenty', 'orange', 'three', 'ripe', 'enough', 'eat', 'still', 'need', 'buy', 'fifteen', 'tomorrow', 'crazy', 'much', 'fruit', 'cost', 'day']
